# %%
import numpy as np

# %%
new_path = "C:/Users/admin/RewardSizeDecoder pipeline/RewardSizeDecoder/results/processed video - fps 5 Hz/464724/session1/downsampled_video_cam0.npy"
old_path = "C:/Users/admin/RewardSizeDecoder pipeline/RewardSizeDecoder/results/cropped- video frame rate 5 Hz/downsampled_n_v_data/464724/session1/downsampled_video_cam0.npy"

# %%
new_downsample_video = np.load(new_path)
old_downsample_video = np.load(old_path)

# %%
np.all(new_downsample_video == old_downsample_video)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 np.all(new_downsample_video == old_downsample_video)
#
# ValueError: operands could not be broadcast together with shapes (17203,128,128) (17196,120,115)
